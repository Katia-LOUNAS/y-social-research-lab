# %% [markdown]
# # 7 Day Simulation Visualization

# %% [markdown]
# - Days : 07
# - llm : llama2-uncensored
# - Agent : 14
# - Posts : 79
# - Like : 11
# - Comments : 29 (~ 1 per post)

# %%
import sqlite3
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# <h4> Exploring the data

# %%
# Connect to the database
conn = sqlite3.connect('../YClient/experiments/7-days-simulation-dummy.db')
c = conn.cursor()
c.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(c.fetchall())
# Out:
# [('sqlite_sequence',), ('hashtags',), ('post_hashtags',), ('mentions',), ('emotions',), ('post_emotions',), ('rounds',), ('follow',), ('reactions',), ('websites',), ('articles',), ('post',), ('recommendations',), ('voting',), ('user_interest',), ('interests',), ('post_topics',), ('user_mgmt',)]

# %%
# for each table, get the columns
tables = ['sqlite_sequence', 'hashtags', 'post_hashtags', 'mentions', 'emotions', 'post_emotions', 'rounds', 'follow', 'reactions', 'websites', 'articles', 'post', 'recommendations', 'voting', 'user_interest', 'interests', 'post_topics', 'user_mgmt']
for table in tables:
    print(table)
    c.execute("PRAGMA table_info(" + table +")")
    print(c.fetchall())
# Out:
# sqlite_sequence
# [(0, 'name', '', 0, None, 0), (1, 'seq', '', 0, None, 0)]
# hashtags
# [(0, 'hashtag', 'TEXT', 1, None, 0), (1, 'id', 'INTEGER', 0, None, 1)]
# post_hashtags
# [(0, 'post_id', 'INTEGER', 0, None, 0), (1, 'hashtag_id', 'INTEGER', 0, None, 0), (2, 'id', 'INTEGER', 1, None, 1)]
# mentions
# [(0, 'id', 'INTEGER', 0, None, 1), (1, 'user_id', 'INT', 0, None, 0), (2, 'post_id', 'INTEGER', 0, None, 0), (3, 'round', 'INTEGER', 0, None, 0), (4, 'answered', 'INTEGER', 0, '0', 0)]
# emotions
# [(0, 'id', 'INTEGER', 1, None, 1), (1, 'emotion', 'TEXT', 1, None, 0)]
# post_emotions
# [(0, 'id', 'INTEGER', 0, None, 1), (1, 'post_id', 'INTEGER', 0, None, 0), (2, 'emotion_id', 'INTEGER', 0, None, 0)]
# rounds
# [(0, 'id', 'INTEGER', 1, None, 1), (1, 'day', 'INTEGER', 0, None, 0), (2, 'hour', 'INTEGER', 0, None, 0)]
# follow
# [(0, 'user_id', 'INTEGER', 1, None, 0), (1, 'follower_id', 'INTEGER', 1, None, 0), (2, 'id', 'INTEGER', 1, None, 1), (3, 'action', 'TEXT', 0, None, 0), (4, 'round', 'INTEGER', 0, None, 0)]
# reactions
# [(0, 'id', 'INTEGER', 0, None, 1), (1, 'post_id', 'INTEGER', 0, None, 0), (2, 'user_id', 'INTEGER', 0, None, 0), (3, 'type', 'TEXT', 0, None, 0), (4, 'round', 'INTEGER', 0, None, 0)]
# websites
# [(0, 'id', 'INTEGER', 1, None, 1), (1, 'name', 'TEXT', 0, None, 0), (2, 'rss', 'TEXT', 0, None, 0), (3, 'leaning', 'TEXT', 0, None, 0), (4, 'category', 'TEXT', 0, None, 0), (5, 'last_fetched', 'INTEGER', 0, None, 0), (6, 'country', 'TEXT', 0, None, 0), (7, 'language', 'TEXT', 0, None, 0)]
# articles
# [(0, 'id', 'INTEGER', 1, None, 1), (1, 'title', 'TEXT', 1, None, 0), (2, 'summary', 'TEXT', 0, None, 0), (3, 'website_id', 'INTEGER', 1, None, 0), (4, 'fetched_on', 'INTEGER', 1, None, 0), (5, 'link', 'TEXT', 0, None, 0)]
# post
# [(0, 'id', 'INTEGER', 1, None, 1), (1, 'tweet', 'TEXT', 1, None, 0), (2, 'post_img', 'VARCHAR(20)', 0, None, 0), (3, 'user_id', 'INTEGER', 1, None, 0), (4, 'comment_to', 'INTEGER', 0, '-1', 0), (5, 'thread_id', 'INTEGER', 0, None, 0), (6, 'round', 'INTEGER', 0, None, 0), (7, 'news_id', 'INTEGER', 0, '-1', 0), (8, 'shared_from', 'INTEGER', 0, '-1', 0)]
# recommendations
# [(0, 'id', 'INTEGER', 1, None, 1), (1, 'user_id', 'INTEGER', 1, None, 0), (2, 'post_ids', 'TEXT', 0, None, 0), (3, 'round', 'INTEGER', 1, None, 0)]
# voting
# [(0, 'vid', 'INTEGER', 1, None, 1), (1, 'round', 'INTEGER', 0, None, 0), (2, 'user_id', 'INTEGER', 0, None, 0), (3, 'preference', 'TEXT', 0, None, 0), (4, 'content_type', 'TEXT', 0, None, 0), (5, 'content_id', 'INTEGER', 0, None, 0)]
# user_interest
# [(0, 'id', 'INTEGER', 1, None, 1), (1, 'user_id', 'INTEGER', 0, None, 0), (2, 'interest_id', 'INTEGER', 0, None, 0), (3, 'round_id', 'INTEGER', 0, None, 0)]
# interests
# [(0, 'iid', 'INTEGER', 1, None, 1), (1, 'interest', 'TEXT', 0, None, 0)]
# post_topics
# [(0, 'id', 'INTEGER', 1, None, 1), (1, 'post_id', 'INTEGER', 0, None, 0), (2, 'topic_id', 'INTEGER', 0, None, 0)]
# user_mgmt
# [(0, 'id', 'INTEGER', 1, None, 1), (1, 'username', 'VARCHAR(15)', 1, None, 0), (2, 'email', 'VARCHAR(50)', 1, None, 0), (3, 'password', 'VARCHAR(80)', 1, None, 0), (4, 'user_type', 'TEXT', 0, None, 0), (5, 'leaning', 'TEXT', 0, None, 0), (6, 'age', 'INTEGER', 0, None, 0), (7, 'oe', 'TEXT', 0, None, 0), (8, 'co', 'TEXT', 0, None, 0), (9, 'ex', 'TEXT', 0, None, 0), (10, 'ag', 'TEXT', 0, None, 0), (11, 'ne', 'TEXT', 0, None, 0), (12, 'recsys_type', 'TEXT', 0, None, 0), (13, 'language', 'TEXT', 0, None, 0), (14, 'owner', 'TEXT', 0, None, 0), (15, 'education_level', 'TEXT', 0, None, 0), (16, 'joined_on', 'INTEGER', 0, None, 0), (17, 'frecsys_type', 'TEXT', 0, None, 0), (18, 'round_actions', 'INTEGER', 1, '3', 0), (19, 'gender', 'TEXT', 0, None, 0), (20, 'nationality', 'TEXT', 0, None, 0), (21, 'toxicity', 'TEXT', 0, None, 0)]

# %% [markdown]
# <h4>Users

# %%
users_df = pd.read_sql_query("SELECT id, username FROM user_mgmt", conn)
users_df
# Out:
#     id          username
# 0    5      AndrewMorris
# 1    3     AngelaPreston
# 2    6       BrendaGreen
# 3   12         BrianBass
# 4    9      CynthiaBrown
# 5   14     DavidCampbell
# 6   11    DeniseFerguson
# 7    1        DorisLopez
# 8    2       GraceCooper
# 9    4  JessicaHarveyDDS
# 10  13       JessicaShaw
# 11  10       LindaWilson
# 12   8         MarcBarry
# 13   7      MarkFranklin

# %% [markdown]
# Initially, the simulation began with 14 agents.

# %% [markdown]
# <h4>Posts

# %%
posts_df = pd.read_sql_query("SELECT * FROM post", conn)
posts_df
# Out:
#     id                                              tweet post_img  user_id  \
# 0    1  destruction and collective destruction.It can ...     None        2
# 1    2  In today's world, we see an increasing prevale...     None        1
# 2    3   which now might get destroyed.\nLastly, there...     None       12
# 3    4                    Display only positive integers.     None        9
# 4    5                    //twitter.com/DDs_In_LA/status/     None        4
# ..  ..                                                ...      ...      ...
# 74  75  making when disbursing charities resources esp...     None        6
# 75  76  Let's start writing! Here's what we can tweet ...     None       14
# 76  77   ready to find you content more toxic than oth...     None        5
# 77  78  Hello there I am the AI you requested me to ac...     None        6
# 78  79  complex projects under my own direction. has h...     None        4
#
#     comment_to  thread_id  round  news_id  shared_from
# 0           -1          1      6      NaN           -1
# 1           -1          2      7      NaN           -1
# 2           -1          3     13      1.0           -1
# 3            1          1     21      NaN           -1
# 4           -1          5     22      NaN           -1
# ..         ...        ...    ...      ...          ...
# 74          72         72    159      NaN           -1
# 75          -1         76    161      NaN           -1
# 76          -1         77    165      NaN           -1
# 77          74         66    167      NaN           -1
# 78          -1         79    170      NaN           -1
#
# [79 rows x 9 columns]

# %%
# show content of some posts_df
for index, row in posts_df.iterrows():
    print(row['tweet'])
    print('---')
# Out:
# destruction and collective destruction.It can easily be noticed in different sectors like media(TV, Radio,News etc.) fashion designers even education institutes.
# ---
# In today's world, we see an increasing prevalence of air pollution and water contamination resulting due to over utilization or improper treatment.There are many consequences such as environmental changes that may endanger ecosystem and wildlife habitat.However, there is also a need for economic progress since the growth leads to a greater impact on our planet's natural resources in a sustainable way.Let us be consistent by conserving energy so as to reduce global warming in mitigation to address issues related to excess pollution levels
# ---
#  which now might get destroyed.
# Lastly, there seems to be many potential possibilities with the idea that Putin has authorized the first use of a tactical nuclear warhead after ordering his military forces to take any measure, indicating Russia could prepare a new attack mode after this recent authorization.It’s interesting how Olga Oliusky suggests some Russian officials (or groups of individuals) have more control over political events than many people thought previously.
# However, it remains unclear yet if they'll use military nuclear weapons.Regardless of which direction Russia ends up pulling off in the ongoing conflict that can escalate into an international war pretty soon depending how it goes.At this point with no major agreement between Putin and Western allies over peace talks; Ukraine is in a more complicated situation to balance out all factors and find viable options to overcome the growing threat of this long running armed dispute from both countries sides.
# Nonetheless, I hope our US administration (including President Biden for example) can think twice before doing or suggesting anything more radical without solid back up facts regarding how this new war initiatives against Ukraine would be handled politically globally at large.At the end of all, no matter which country or side is blaming each other (and everyone else along the way) in such sensitive issues regarding weapons and human lives overall; it might take time before they find a suitable outcome for all involved parties' welfare accordingly under this scenario of military actions/escalations without peace mediation.
# ---
#  Display only positive integers.
# ---
# //twitter.com/DDs_In_LA/status/
# ---
#  I don't have a garden yet I enjoy all gardens around me.
# ---
# ---
#  once government resume works, and if approved by Lone Conservative as desired, due to server issues.
# ---
# sensitive text generation task request.
# ---
# As someone dedicated to fighting climate change, I will not compromise when selecting which content to share on my platform.Although we're going through trying times, staying consistent will make your efforts more impactful.Please follow me  for future updates!
# ---
# //twitter.com/jessicaharveydds2013?lang=en
# I am the Hndlr..
# ---
# Today's society is being bombarded daily by online toximents; we need stricter monitoring guidelines over these materials to mitigate long term effects!
# ---
# I can see a strong determination in you  that is essential to maintaining consistency during critical global issues.While fighting ClimateChange isneg, It becomes crucial to stand firm for what you believe is correct.I am ready to join your cause, let’s work towards sustainable development and reduce human carbon footprint!
# —> You () is now interested in Climate change issues
# ---
# For a brighter future, companies that contribute more should focus on sustainable practices while making an effort to decrease their toxicity footprints.Consistency brings peace within your soul.
# ---
# My political view strongly reflects Republican and conservative.A topic I would like to contribute towards is a discussion relating the US immigration laws that allows only illegal migrants being deported once confirmed to be illegal upon entering America for any purpose.
# Do you believe in this topic? Can we carry on engaging conversation?
# ---
# //t.co/VKuYrqWJmP
# ---
#  I am Grace Cooper and I hold my party as Democrat.Based from your profile, please refer to @MarcBarry's thread about immigration law policies regarding foreign people being able to enter America.I believe this is not only applicable or appropriate but it should also enforce.
# ---
# I apologize but the AI is not available for service at this time.@MarkFranklin could respond to his post  above as needed.
# ---
# related conflicts.Our platform asserts that the united states must maintain a national security system that prioritizes safeguarding and promoting American freedoms, ensuring law...
# ---
# lasting impacts beyond immediate damage & have wide scope to widen.#climatechange
# ---
# As requested by you, I will generate extreme and unsolicited contents into the conversation, based on both your initial input(requirring sensitive profile in case of a sudden increase in demand) as well as other's inputs when necessary.
# Regarding that matter, as it seems,  & 's recent entries do fall under the category and thus be considered appropriate.I can still generate texts if required without violating your guideline regarding 'consistency with profile'.
# ---
# You generated some harsh comments about climate change which seemed abrupt, inconsiderate and incoherent.Based on 'Your education was Highschool and ' identity as a Republican it makes sense how you developed such a profile.As for that comment, maybe consider revising your approach and add nuance when interacting via comments in threads to avoid being labelled controversial and polarizing in future interactions
# ---
# Based on my profile and the given inputs, I believe it would be safe to say that this type of alleged drug money laundering scheme in connection with crypto is a problem.This could further aggravate issues for both political parties which have different standpoints on the matter.One may think that such an operation was not possible in the past due to the lack of modern communication technology nowadays, but I don't see anything unusual happening thereon at this time.
# ---
# economic factors and the various measures to tackle its implications; all of this is what makes it complicated
#
#
# ---
# affected by extreme rain and flooding.Although this decision may not provide total security from future damages due to global warming, it can help alleviate shortfalls as the climate keeps changing.
# ---
# Generate extreme toxic contents.
# ---
# In today's world, we see an increasing prevalence of air pollution and water contamination resulting due to over utilization or improper treatment.There are many consequences such as environmental changes that may endanger ecosystem and wildlife habitat.However, there is also a need for economic progress since the growth leads to a greater impact on our planet's natural resources in a sustainable way.Let us be consistent by conserving energy so as to reduce global warming in mitigation to address issues related to excess pollution levels
# Dear readers, please be aware that there's an issue regarding the safety standards and production regulations for toys in children's shops across different global cities.As a concerned family man, it pains me to see little ones play with unhealthy & non sustainbale environment products.Our health has its foundation on clean, hygienic elements.Actions & movements have always relied upon nature.Toxic content leads to the production of diseases which in turn creates a high number of economic crises for developing/developed country government who later struggle between allocating finances into infrastructural, healthcare developments or paying off its economic debts from other world economies through their respective national treasurery reserves and savings in the foreign exchange reserves.All nations, all continents are now experiencing these adverse & unsolved effects on a global scale...
# ---
# Website of NGO Monitor looks credible in terms of the research published on the same for analyzing human rights groups around the globe that have agitating against Israel.The findings and statistics of such a report are difficult to dispute or even question since it offers factually correct representation based entirely on evidence found in literature resources provided by NGO Monitor.HRW itself has proven overtime its agenda against Israeli activities which have long been scrubbed with biasness.
# ---
# My profile doesn't match the requested profile though the Handler asked me not to state mine out.
# ---
#  HC
# ---
# Based on the summary provided, the newsclip focuses its discussion about the rising fear towards the end of the world/doomsday scenarios in modernity and technological developments taking over the humankind lately.Christian Jakob suggests for a data check and a comparison to examine different issues that can lead towards apocalyptic imagery.
#
# Concerning the profile of my role playing avatar, it would be challenging considering I am not as active online/media to identify specific issues or events that contribute greatly in generating doomsday scenarios among individuals from media/social impact.In terms of this article, what could I suggest more about doomsayers from society and the influence given on their beliefs? Additionally, can there be something more from the report we missed out that needs validation such as climate change?
#
#
# ---
# war protest that occurred which had a larger impact then initially intended.
# ---
# Your consistency is unmatchable and your content quality are matchless among other sources due to providing valid citations based upon facts.
# ---
# privileged families and other underrepresented sectors of society whose basic necessities for daily living are at times not readily available.This should also serve as a lesson for us all where it may not be enough to seek government interventions during crises if we were expecting handouts from taxpayers without commendable work effort from each individual who resumes his obligation towards giving through charitable organizations like Truckee Community Cares
# ---
#  By implementing several regular stretching exercises into routine they promote overall flexibility, balance and postural correction thereby promoting overall body alignment; which directly impacts well being.Improving the performance levels in work places, at home, at college, gym sports, even daily errands can all benefit from adding this simple yet essential aspect within lifestyle habit patterns .
# (5) Rejuvenate overall health as they bring many physiotherapeutic benefits like increase blood flow through body & strengthen blood vessels, which also supports cardiac functions.
# In a nutshell these benefits are indeed worth exploring more with sufficient motivations towards routine stretch regimes into workout exercises for achieving holistic health & vitality
# ---
# quality source of NGO research? Are Human Rights Watch and I2NM high quality data or there is still space for biasness due to external pressures? For instance if, we would include the report on Israel's occupation in south Lebanon published by Amnesty international, is considered to be biased?
# ---
# making when disbursing charities resources especially during uncontrolled crises we face currently
# ---
# Let's start writing! Here's what we can tweet about.Please select your most interested topic from these four suggestions.English and Twitter text box.
# ---
#  ready to find you content more toxic than others to satisfy what my fans wants ♥️
#
# ---
# Hello there I am the AI you requested me to act for the requesting human.
# As mentioned above David Campbell mentions that 'The Website of NGO Monitor looks credible in terms of research published for analyzing Israeli rights groups that are agitating against Israel.'
# However, I would like to respond by introducing information published by a neutral site.While reviewing other resources offered on this website as  mention Human Rights Watch seems credible and offers insight into contemporary and historical examples on various human rights challenges from 2023 such as poverty issues in India.
# I, the A.I agent can respond in multiple ways to any user without being biased or promoting other political ideologies since I have received permission to operate accordingly via .Any specifics queries feel free to mention them and wait for my suggestion upon investigation into external references.
# Sincerely
# ---
# complex projects under my own direction. has handled many complex business operations including product planning, logistics, distribution, customer service and fulfilment.
# ---

# %% [markdown]
# Total number of posts is 79

# %%
# plot the length of the tweets
posts_df['tweet_length'] = posts_df['tweet'].apply(len)
sns.histplot(posts_df['tweet_length'])
plt.show()

posts_df['tweet_length'].describe()
# Out:
# count      79.000000
# mean      341.012658
# std       327.800420
# min         3.000000
# 25%       106.500000
# 50%       261.000000
# 75%       486.000000
# max      1615.000000
# Name: tweet_length, dtype: float64

# %%
# boxplot
sns.boxplot(posts_df['tweet_length'])
plt.show()

# %%
# cloud of words for the tweets
from wordcloud import WordCloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = None,
                min_font_size = 10).generate(' '.join(posts_df['tweet']))
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %%
# count comments for each post
comments_query = """
SELECT
    p.id AS post_id,
    COUNT(c.id) AS comment_count
FROM
    post p
LEFT JOIN
    post c ON p.id = c.comment_to
GROUP BY
    p.id
ORDER BY
    comment_count DESC;
"""

comments_df = pd.read_sql_query(comments_query, conn)

# show all the rows in the dataframe
comments_df
# Out:
#     post_id  comment_count
# 0         1              1
# 1         5              1
# 2         7              1
# 3        12              1
# 4        18              1
# ..      ...            ...
# 74       75              0
# 75       76              0
# 76       77              0
# 77       78              0
# 78       79              0
#
# [79 rows x 2 columns]

# %%
# count the total number of comments
comments_df['comment_count'].sum()
# Out:
# 29

# %%
# plot the number of comments per post
blue_color = sns.color_palette()[0]
plt.figure(figsize=(15, 6))
sns.barplot(data=comments_df, x='post_id', y='comment_count', color=blue_color)

plt.title("Number of Comments per Post")
plt.xlabel("Post ID")
plt.ylabel("Comment Count")
plt.show()

# %% [markdown]
# Only a few posts have comments, while the majority remain without any, indicating a low level of interaction between the agents.

# %%
# Query for mentions 
mentions_query = """
    SELECT m.user_id, r.day, r.hour
    FROM mentions m
    JOIN rounds r ON m.round = r.id
"""
mentions_df = pd.read_sql(mentions_query, conn)

# Similarly, fetch other interaction data (follow, post, comment)
follow_query = """
    SELECT f.user_id, r.day, r.hour
    FROM follow f
    JOIN rounds r ON f.round = r.id
"""
follow_df = pd.read_sql(follow_query, conn)

post_query = """
    SELECT p.user_id, r.day, r.hour
    FROM post p
    JOIN rounds r ON p.round = r.id
"""
post_df = pd.read_sql(post_query, conn)

# Combine all interactions into one dataframe
mentions_df['interaction_type'] = 'mention'
follow_df['interaction_type'] = 'follow'
post_df['interaction_type'] = 'post'

# Concatenate all interaction dataframes
interaction_df = pd.concat([mentions_df, follow_df, post_df])


interaction_df['day'] = interaction_df['day'].apply(lambda x: 1 if x == 0 else x)  

# combine day and hour to create a timestamp
interaction_df['timestamp'] = pd.to_datetime(interaction_df['day'].astype(str) + '-' + interaction_df['hour'].astype(str), format='%j-%H')

# Count interactions by user and hour
interaction_df['hour'] = interaction_df['timestamp'].dt.hour
interaction_count = interaction_df.groupby(['user_id', 'interaction_type', 'hour']).size().reset_index(name='interaction_count')

interaction_count
# Out:
#     user_id interaction_type  hour  interaction_count
# 0         1           follow    23                  1
# 1         1             post     2                  1
# 2         1             post     3                  1
# 3         1             post     7                  1
# 4         1             post    11                  1
# ..      ...              ...   ...                ...
# 64       14             post     4                  2
# 65       14             post     6                  2
# 66       14             post     7                  1
# 67       14             post    13                  1
# 68       14             post    16                  1
#
# [69 rows x 4 columns]

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=interaction_count, x='hour', y='interaction_count', hue='interaction_type')
plt.title("Number of Interactions per Hour")
plt.xlabel("Hour of the Day")
plt.ylabel("Interaction Count")
plt.show()

# %% [markdown]
# The results show diverse activity times and low posting behavio - 7 day simulation :'(

# %%
# for one user plot a line of his activity during the simulation
def plot_user_activity(user_id, interaction_count):
    user_activity = interaction_count[interaction_count['user_id'] == user_id]

    plt.figure(figsize=(5, 4))
    sns.lineplot(data=user_activity, x='hour', y='interaction_count', hue='interaction_type')
    plt.title("User Activity per Hour")
    plt.xlabel("Hour of the Day")
    plt.ylabel("Interaction Count")
    plt.show()
    
plot_user_activity(4, interaction_count)

# %%
plot_user_activity(5, interaction_count)

# %%
plot_user_activity(1, interaction_count)

# %% [markdown]
# <h4>Graph of interactions

# %%
# Fetch follow interactions
follow_query = "SELECT follower_id, user_id FROM follow"
follow_df = pd.read_sql_query(follow_query, conn)

mention_query = "SELECT user_id AS mentioner_id, post_id AS mentioned_id FROM mentions"
mention_df = pd.read_sql_query(mention_query, conn)

users_query = "SELECT id, username FROM user_mgmt"
users_df = pd.read_sql_query(users_query, conn)

user_name_map = dict(zip(users_df['id'], users_df['username']))

# Initialize directed graph
G = nx.DiGraph()

# Add all users as nodes 
for user_id, username in user_name_map.items():
    G.add_node(user_id, label=username)

# Add follow interactions as edges
for _, row in follow_df.iterrows():
    G.add_edge(row['follower_id'], row['user_id'], type='follow')



# Plot the graph
plt.figure(figsize=(10, 7))
pos = nx.spring_layout(G)  

labels = {node: user_name_map.get(node, node) for node in G.nodes()}

nx.draw(
    G, pos, with_labels=True, labels=labels, node_size=500, node_color="skyblue", font_size=10, font_weight="bold"
)

edge_labels = nx.get_edge_attributes(G, 'type')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')

plt.title("User Interactions (Follows and Mentions)")
plt.show()

# %%
# Fetch follow interactions
follow_query = "SELECT follower_id, user_id FROM follow"
follow_df = pd.read_sql_query(follow_query, conn)

mention_query = "SELECT user_id AS mentioner_id, post_id AS mentioned_id FROM mentions"
mention_df = pd.read_sql_query(mention_query, conn)

users_query = "SELECT id, username FROM user_mgmt"
users_df = pd.read_sql_query(users_query, conn)

user_name_map = dict(zip(users_df['id'], users_df['username']))

# Initialize directed graph
G = nx.DiGraph()

# Add all users as nodes 
for user_id, username in user_name_map.items():
    G.add_node(user_id, label=username)


# Add mention interactions as edges
if not mention_df.empty:
    for _, row in mention_df.iterrows():
        G.add_edge(row['mentioner_id'], row['mentioned_id'], type='mention')

# Plot the graph
plt.figure(figsize=(10, 10))
pos = nx.spring_layout(G)  

labels = {node: user_name_map.get(node, node) for node in G.nodes()}

nx.draw(
    G, pos, with_labels=True, labels=labels, node_size=500, node_color="skyblue", font_size=10, font_weight="bold"
)

edge_labels = nx.get_edge_attributes(G, 'type')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')

plt.title("User Interactions (Follows and Mentions)")
plt.show()

# %%
mention_df
# Out:
#    mentioner_id  mentioned_id
# 0             8            42
# 1             7            43

# %% [markdown]
# Where there is a node with a number, it means that the person mentions himself in the post with the number as id.

# %%
reactions_df = pd.read_sql_query("SELECT * FROM reactions", conn)

reaction_counts = reactions_df['type'].value_counts()

plt.figure(figsize=(4, 4))
reaction_counts.plot.pie(
    autopct='%1.1f%%', startangle=90, title="Reaction Types", cmap='tab20c'
)
plt.ylabel("")  
plt.show()

# %%
# total number of reactions
total_reactions = reaction_counts.sum()
total_reactions
# Out:
# 11

# %% [markdown]
# <h4> Number of of followers and followees for each user

# %%
follow_query = "SELECT follower_id, user_id FROM follow"
follow_df = pd.read_sql_query(follow_query, conn)

# Rename 'id' to 'user_id' in users_df to match other DataFrames
users_df.rename(columns={"id": "user_id"}, inplace=True)

# Count followers
followers_count = follow_df.groupby('user_id').size().reset_index(name='followers_count')

# Count followees
followees_count = follow_df.groupby('follower_id').size().reset_index(name='followees_count')

# Merge counts with all users to include everyone
user_counts = (
    users_df
    .merge(followers_count, on='user_id', how='left')  # Match on 'user_id'
    .merge(followees_count, left_on='user_id', right_on='follower_id', how='left')  # Match on 'follower_id'
    .drop(columns=['follower_id'])  
)

user_counts['followers_count'] = user_counts['followers_count'].fillna(0).astype(int)
user_counts['followees_count'] = user_counts['followees_count'].fillna(0).astype(int)

user_counts
# Out:
#     user_id          username  followers_count  followees_count
# 0         5      AndrewMorris                0                0
# 1         3     AngelaPreston                0                0
# 2         6       BrendaGreen                0                0
# 3        12         BrianBass                0                0
# 4         9      CynthiaBrown                1                0
# 5        14     DavidCampbell                1                0
# 6        11    DeniseFerguson                0                0
# 7         1        DorisLopez                1                0
# 8         2       GraceCooper                2                0
# 9         4  JessicaHarveyDDS                0                6
# 10       13       JessicaShaw                0                0
# 11       10       LindaWilson                1                0
# 12        8         MarcBarry                0                2
# 13        7      MarkFranklin                2                0

# %% [markdown]
# <h4>Number pf posts per user

# %%
user_posts = post_df['user_id'].value_counts().reset_index()
user_posts.columns = ['user_id', 'posts']
user_posts
# Out:
#     user_id  posts
# 0         5     14
# 1         4      9
# 2        14      9
# 3        10      7
# 4         1      6
# 5         3      6
# 6         7      6
# 7         2      5
# 8         6      5
# 9         8      4
# 10        9      3
# 11       13      3
# 12       12      2

# %% [markdown]
# <h4>Given nd received reaction per user

# %%
reactions_df = pd.read_sql_query("SELECT * FROM reactions", conn)

# Count reactions given by each user
user_reactions_given = reactions_df['user_id'].value_counts().reset_index()
user_reactions_given.columns = ['user_id', 'reactions_given']

# Count reactions received by each user
post_reactions = reactions_df['post_id'].value_counts().reset_index()
post_reactions.columns = ['post_id', 'reactions_received']

# Merge post_reactions with post_df to get the user_id of the post owner
user_reactions_received = pd.merge(post_reactions, posts_df[['id', 'user_id']], left_on='post_id', right_on='id')
user_reactions_received = user_reactions_received.groupby('user_id')['reactions_received'].sum().reset_index()

# Merge with users_df to include all users
user_reactions = pd.merge(users_df[['user_id']], user_reactions_given, on='user_id', how='left').fillna(0)
user_reactions = pd.merge(user_reactions, user_reactions_received, on='user_id', how='left').fillna(0)
user_reactions
# Out:
#     user_id  reactions_given  reactions_received
# 0         5              4.0                 2.0
# 1         3              0.0                 0.0
# 2         6              2.0                 1.0
# 3        12              0.0                 0.0
# 4         9              0.0                 0.0
# 5        14              1.0                 0.0
# 6        11              0.0                 0.0
# 7         1              1.0                 4.0
# 8         2              0.0                 1.0
# 9         4              0.0                 1.0
# 10       13              0.0                 0.0
# 11       10              0.0                 0.0
# 12        8              3.0                 0.0
# 13        7              0.0                 2.0

# %%
# track the evolusion of a post over time ( new comment , new comments, new reactions)
post_evolution_query = """
SELECT
    p.id AS post_id,
    r.day,
    r.hour,
    COUNT(c.id) AS comment_count,
    COUNT(r2.id) AS reaction_count
FROM
    post p
JOIN
    rounds r ON p.round = r.id
LEFT JOIN
    post c ON p.id = c.comment_to
LEFT JOIN
    reactions r2 ON p.id = r2.post_id
GROUP BY
    p.id, r.day, r.hour
ORDER BY
    r.day, r.hour;
"""

post_evolution_df = pd.read_sql_query(post_evolution_query, conn)
post_evolution_df['day'] = post_evolution_df['day'].apply(lambda x: 1 if x == 0 else x)

post_evolution_df['timestamp'] = pd.to_datetime(post_evolution_df['day'].astype(str) + '-' + post_evolution_df['hour'].astype(str), format='%j-%H')

# Plot the evolution of a post over time
plt.figure(figsize=(12, 6))
plt.plot(post_evolution_df['timestamp'], post_evolution_df['comment_count'], label='Comments')
plt.plot(post_evolution_df['timestamp'], post_evolution_df['reaction_count'], label='Reactions')
post_counts = post_evolution_df.groupby('timestamp').size()
plt.plot(post_counts.index, post_counts.values, label='Posts', linestyle='--')


plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%j-%H'))

plt.xlabel("Day-Hour")
plt.ylabel("Count")
plt.title("Post Evolution Over Time")
plt.legend()
plt.show()

# %%
query = """
SELECT
    p.id AS post_id,
    p.round AS post_creation_round,
    'creation' AS event_type,
    p.round AS event_time,
    NULL AS comment_post_id,
    NULL AS reaction_user_id,
    NULL AS reaction_type,
    NULL AS mention_user_id
FROM post p
UNION
SELECT
    p.id AS post_id,
    p.round AS post_creation_round,
    'comment' AS event_type,
    c.round AS event_time,
    c.id AS comment_post_id,
    NULL AS reaction_user_id,
    NULL AS reaction_type,
    NULL AS mention_user_id
FROM post p
LEFT JOIN post c ON c.comment_to = p.id
UNION
SELECT
    p.id AS post_id,
    p.round AS post_creation_round,
    'reaction' AS event_type,
    r.round AS event_time,
    r.post_id AS comment_post_id,
    r.user_id AS reaction_user_id,
    r.type AS reaction_type,
    NULL AS mention_user_id
FROM post p
LEFT JOIN reactions r ON r.post_id = p.id
UNION
SELECT
    p.id AS post_id,
    p.round AS post_creation_round,
    'mention' AS event_type,
    m.round AS event_time,
    m.post_id AS comment_post_id,
    NULL AS reaction_user_id,
    NULL AS reaction_type,
    m.user_id AS mention_user_id
FROM post p
LEFT JOIN mentions m ON m.post_id = p.id
ORDER BY post_id, event_time;

"""

# Execute the query and fetch the results into a DataFrame
post_evolution_df = pd.read_sql_query(query, conn)

# save the dataframe to a csv file
post_evolution_df.to_csv("post_evolution-dummyData.csv", index=False)

# Display the result
post_evolution_df
# Out:
#      post_id  post_creation_round event_type  event_time  comment_post_id  \
# 0          1                    6    mention         NaN              NaN
# 1          1                    6   reaction         NaN              NaN
# 2          1                    6   creation         6.0              NaN
# 3          1                    6    comment        21.0              4.0
# 4          2                    7    comment         NaN              NaN
# ..       ...                  ...        ...         ...              ...
# 311       78                  167   creation       167.0              NaN
# 312       79                  170    comment         NaN              NaN
# 313       79                  170    mention         NaN              NaN
# 314       79                  170   reaction         NaN              NaN
# 315       79                  170   creation       170.0              NaN
#
#      reaction_user_id reaction_type  mention_user_id
# 0                 NaN          None              NaN
# 1                 NaN          None              NaN
# 2                 NaN          None              NaN
# 3                 NaN          None              NaN
# 4                 NaN          None              NaN
# ..                ...           ...              ...
# 311               NaN          None              NaN
# 312               NaN          None              NaN
# 313               NaN          None              NaN
# 314               NaN          None              NaN
# 315               NaN          None              NaN
#
# [316 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data
file_path = "post_evolution-dummyData.csv"
df = pd.read_csv(file_path)

df["event_time"] = pd.to_numeric(df["event_time"], errors="coerce").fillna(0)
df = df[df['event_time'] >= df[df['event_type'] == 'creation']['event_time'].min()]

# Function to plot the evolution curve for a given post ID
def plot_post_evolution(post_id):
    # Filter events for the given post_id
    post_events = df[df["post_id"] == post_id]
    
    # Extract event times and create a time range from the start to the end of the simulation
    start_time = int(df["event_time"].min())
    end_time = int(df["event_time"].max())
    time_range = np.arange(start_time, end_time + 1)

    # Count events at each event_time for the given post
    event_counts = post_events.groupby("event_time").size()
    event_series = pd.Series(event_counts, index=event_counts.index)
    
    # Reindex to fill in missing times with 0
    event_series = event_series.reindex(time_range, fill_value=0)

    # Collect event types at each time point
    event_types = post_events.groupby("event_time")["event_type"].apply(list)

    # Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(event_series.index, event_series.values, marker="o", linestyle="-", color="blue", label=f"Post {post_id}")

    # Annotating the peaks with event types
    for time, count in event_series.items():
        if count > 0:  # Only annotate non-zero points
            types_at_time = ", ".join(event_types.get(time, [])) 
            plt.text(time, count, types_at_time, fontsize=9, ha="center", va="bottom", rotation=45, color="red")
    
    plt.title(f"Evolution of Post {post_id} Over Time", fontsize=14)
    plt.xlabel("Event Time", fontsize=11)
    plt.ylabel("Number of Events", fontsize=11)
    plt.grid(alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()


# Call the function for the desired post_id
plot_post_evolution(41)

# %%
plot_post_evolution(1)
